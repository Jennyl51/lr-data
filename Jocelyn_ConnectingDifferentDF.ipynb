# %% [markdown]
# # LumenRoute Data Processing Assignment 2

# %% [markdown]
# Meeting Notes: 10/9/2025, Created by Jocelyn Wu (jocelyn.wu@berkeley.edu)
#
# Data Sources:
# - [Calls of Service](https://bpd-transparency-initiative-berkeleypd.hub.arcgis.com/datasets/3be134af40954e19a3d308779a65f175_0/explore)
#     - Datasets for calls for service from 2021 - 2025
#     - Last Updated on 10/09/2025
#     - Number of Row: 293,871
#
# - [Berkeley PD Arrest](https://bpd-transparency-initiative-berkeleypd.hub.arcgis.com/datasets/1c7ee9682ff84bf08bc833e43ab6286b_0/explore)
#     - Dataset for Berkeley PD Arrests from 2016 - Current
#     - Last Updated on 10/09/2025)
#     - Number of Rows: 136,411 rows
#
# There are a two main goals in this assignment
#     (1) combine these two datasets into one
#     (2) keep the "important" columns that will help with calculating the crime weightage,

# %%
import pandas as pd

# %% [markdown]
# ## Goal #1 and #2: Combine these Two Datasets into One & Keep Important Columns

# %%
# import all 3 datasets

# %%
calls_for_service = pd.read_csv("Data/callsforservice.csv")

# %%
calls_for_service.head(5)
# Out:
#   Incident_Number          CreateDatetime                     Call_Type  \
# 0   2025-00047224  2025/10/16 12:14:59+00      CFS SUSCIR - Susp. Circ.
# 1   2025-00047221  2025/10/16 11:39:28+00  CFS 1124 - Abandoned Vehicle
# 2   2025-00047220  2025/10/16 11:12:52+00         CFS 415 - Disturbance
# 3   2025-00047219  2025/10/16 11:00:03+00            CFS 459 - Burglary
# 4   2025-00047218  2025/10/16 10:42:06+00     CFS 1033A - Audible Alarm
#
#       Source     Progress Priority               Dispositions  \
# 0  Telephone  In Progress  Level 2                        NaN
# 1  Telephone  Cold Report  Level 4                        NaN
# 2  Telephone  In Progress  Level 2         MDT Narrative Only
# 3   911 Call  In Progress  Level 1                        NaN
# 4  Telephone  In Progress  Level 3  Building Secure and Tight
#
#                Block_Address      City  ZIP_Code NonBerkeley_Address  ObjectId
# 0           1000 CARLETON ST  BERKELEY   94710.0                 NaN         1
# 1         2100 SAN PABLO AVE  BERKELEY   94702.0                 NaN         2
# 2  VIRGINIA ST  &  CURTIS ST  BERKELEY   94702.0                 NaN         3
# 3            2500 DURANT AVE  BERKELEY   94704.0                 NaN         4
# 4              700 GILMAN ST  BERKELEY   94710.0                 NaN         5

# %%
arrest_log = pd.read_csv("Data/arrest_log.csv")

# %%
arrest_log.head(5)
# Out:
#                                        Statute  \
# 0                              484G; 530.5 (A)
# 1                               Warr - BPD (M)
# 2                      1203.2 - F; 422 (A) - F
# 3                               Warr - Out (F)
# 4  1203.2 - F; 594 (B)(1); 11364(A); 148(A)(1)
#
#                                  Statute_Description  \
# 0  FELONY-THEFT BY USE OF ACCESS CARD INFORMATION...
# 1                                Misdemeanor Warrant
# 2  PROBATION VIOLATION: REARREST/REVOKE; THREATEN...
# 3                             Outside Warrant Felony
# 4  PROBATION VIOLATION: REARREST/REVOKE; VANDALIS...
#
#                                         Statute_Type           Date_and_Time  \
# 0                             Penal Code; Penal Code  2025/09/29 16:00:00+00
# 1                                         Penal Code  2025/09/29 15:33:00+00
# 2                             Penal Code; Penal Code  2025/09/29 14:08:00+00
# 3                                         Penal Code  2025/09/29 12:00:00+00
# 4  Penal Code; Penal Code; Health and Safety; Pen...  2025/09/29 10:40:00+00
#
#    Arrest_Number         Arrest_Type Date_of_Birth   Eyes           Subject  \
# 0          40184  On-View Arrest IBR    1959/10/09   Blue      JAMES HARRIS
# 1          40142  Summoned/Cited IBR    1964/10/22  Hazel     Lance Clouden
# 2          40132  On-View Arrest IBR    1980/09/01  Brown  Stephan Benjamin
# 3          40165  On-View Arrest IBR    1984/08/21  Brown       DORE WALTON
# 4          40144  On-View Arrest IBR    1988/01/15  Brown      JEREMY YOUNG
#
#    Age            Hair        Height   Race     Sex  Weight    Case_Number  \
# 0   66  Gray/Part Gray  5 ft. 10 in.  White    Male   175.0  2025-00026289
# 1   61           White  5 ft. 10 in.  White    Male   155.0  2025-00044294
# 2   45           Black   5 ft. 7 in.  Black    Male   150.0  2025-00044243
# 3   41           Green   5 ft. 5 in.  White  Female   140.0  2025-00032140
# 4   37           Black   6 ft. 4 in.  Black    Male   400.0  2025-00044234
#
#    ObjectId
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
# get rid of the unneeded columns within the Arrest Log 
# (ones that overlap with Calls of Service)

# %%
arrest_log = arrest_log.drop( ["Date_and_Time", "Arrest_Number", "Date_of_Birth", "Eyes", "Subject", "Hair",  ] , axis = "columns")

# %%
calls_for_service.merge(arrest_log, left_on = "Incident_Number" , right_on = "Case_Number" )
# Out:
#     Incident_Number          CreateDatetime                   Call_Type  \
# 0     2025-00047181  2025/10/16 04:31:38+00       CFS 415 - Disturbance
# 1     2025-00047000  2025/10/15 08:30:45+00             CFS 451 - Arson
# 2     2025-00047122  2025/10/15 23:25:12+00   CFS SUSPER - Susp. Person
# 3     2025-00047122  2025/10/15 23:25:12+00   CFS SUSPER - Susp. Person
# 4     2025-00046857  2025/10/14 15:03:35+00   CFS SUSPER - Susp. Person
# ..              ...                     ...                         ...
# 176   2025-00040430  2025/09/08 23:50:09+00     CFS LDRPT - Loud Report
# 177   2025-00038816  2025/08/31 02:19:39+00           CFS 242 - Battery
# 178   2025-00032140  2025/07/21 07:09:33+00  CFS 10851 - Stolen Vehicle
# 179   2025-00026289  2025/06/12 06:07:27+00          CFS 459 - Burglary
# 180   2022-00032558  2022/07/17 16:30:08+00  CFS SUSVEH - Susp. Vehicle
#
#                 Source     Progress Priority  \
# 0             911 Call  In Progress  Level 2
# 1             911 Call  In Progress  Level 1
# 2            Telephone  In Progress  Level 2
# 3            Telephone  In Progress  Level 2
# 4             911 Call  In Progress  Level 2
# ..                 ...          ...      ...
# 176           911 Call  In Progress  Level 1
# 177           911 Call  In Progress  Level 1
# 178          Telephone  In Progress  Level 2
# 179          Telephone  Cold Report  Level 3
# 180  Officer Initiated  In Progress  Level 2
#
#                                           Dispositions  \
# 0                    Primary Case (Case or Cold Theft)
# 1    MDT Narrative Only, Primary Case (Case or Cold...
# 2    Primary Case (Case or Cold Theft), Arrest only...
# 3    Primary Case (Case or Cold Theft), Arrest only...
# 4    Arrest only (no Case), Homeless, Primary Case ...
# ..                                                 ...
# 176       Follow Up, Primary Case (Case or Cold Theft)
# 177                  Primary Case (Case or Cold Theft)
# 178                  Primary Case (Case or Cold Theft)
# 179                  Primary Case (Case or Cold Theft)
# 180          Primary Case (Case or Cold Theft), , RIPA
#
#                       Block_Address      City  ZIP_Code  ...  \
# 0                 2300 SHATTUCK AVE  BERKELEY   94704.0  ...
# 1                   3000 ADELINE ST  BERKELEY   94703.0  ...
# 2               1400 UNIVERSITY AVE  BERKELEY   94702.0  ...
# 3               1400 UNIVERSITY AVE  BERKELEY   94702.0  ...
# 4                 1400 SHATTUCK AVE  BERKELEY   94709.0  ...
# ..                              ...       ...       ...  ...
# 176  2100 MARTIN LUTHER KING JR WAY  BERKELEY   94703.0  ...
# 177           WALNUT ST  &  VINE ST  BERKELEY   94709.0  ...
# 178              2900 HILLEGASS AVE  BERKELEY   94705.0  ...
# 179                   2300 CEDAR ST  BERKELEY   94708.0  ...
# 180             1500 UNIVERSITY AVE  BERKELEY   94703.0  ...
#
#                                    Statute_Description  \
# 0    TRESPASS:REFUSE TO LEAVE PROPERTY; Entering pr...
# 1    CAUSING FIRE OF PROPERTY; POSSESS UNLAWFUL PAR...
# 2    PETTY THEFT SHOPLIFTING; POSSESS CONTROLLED SU...
# 3    All other larceny: FELONY THEFT WITH 2 PRIOR; ...
# 4    Shoplifting: FELONY THEFT WITH 2 PRIORS; PETTY...
# ..                                                 ...
# 176  ASSAULT WITH FIREARM ON PERSON; SHOOT AT INHAB...
# 177                    BATTERY W/SERIOUS BODILY INJURY
# 178                             Outside Warrant Felony
# 179  FELONY-THEFT BY USE OF ACCESS CARD INFORMATION...
# 180  POSSESS STOLEN VEHICLE/VESSEL/ETC; TAKE VEHICL...
#
#                                           Statute_Type         Arrest_Type  \
# 0                  Penal Code; Berkeley Municipal Code  Summoned/Cited IBR
# 1                        Penal Code; Health and Safety  On-View Arrest IBR
# 2            Penal Code; Health and Safety; Penal Code  Summoned/Cited IBR
# 3    Penal Code; Penal Code; Penal Code; Penal Code...  On-View Arrest IBR
# 4    Penal Code; Penal Code; Penal Code; Penal Code...  On-View Arrest IBR
# ..                                                 ...                 ...
# 176                             Penal Code; Penal Code  On-View Arrest IBR
# 177                                         Penal Code  On-View Arrest IBR
# 178                                         Penal Code  On-View Arrest IBR
# 179                             Penal Code; Penal Code  On-View Arrest IBR
# 180                           Penal Code; Vehicle Code  On-View Arrest IBR
#
#     Age        Height      Race     Sex Weight    Case_Number ObjectId_y
# 0    35   5 ft. 2 in.     White  Female  150.0  2025-00047181        104
# 1    43   5 ft. 9 in.     White    Male  150.0  2025-00047000        119
# 2    24   6 ft. 0 in.     White    Male  140.0  2025-00047122        106
# 3    39   5 ft. 8 in.     Other    Male  155.0  2025-00047122        108
# 4    57   5 ft. 9 in.     Black    Male  150.0  2025-00046857        126
# ..   ..           ...       ...     ...    ...            ...        ...
# 176  28   5 ft. 6 in.  Hispanic    Male  220.0  2025-00040430         27
# 177  69  5 ft. 10 in.     White    Male  160.0  2025-00038816         63
# 178  41   5 ft. 5 in.     White  Female  140.0  2025-00032140          4
# 179  66  5 ft. 10 in.     White    Male  175.0  2025-00026289          1
# 180  52   6 ft. 4 in.     White    Male  280.0  2022-00032558        115
#
# [181 rows x 23 columns]
